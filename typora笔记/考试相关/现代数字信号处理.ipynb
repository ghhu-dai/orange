# %% [markdown]
# ### 1.3 已知随机矢量x的均值为$m_x$,协方差为$\Sigma_x$，估计值为$\hat{x}$,估计误差为$e = x - \hat{x}$,证明：若$E[e,e^T] = Ree = min$,则：$\hat{x} = m_x $而$Ree = \Sigma_x$
#
# <font color = blue>
#
# 证明如下：
#
# 设：$\hat{x} = m_x+a$,其中a为常量
#
# 则：$E(ee^T) = R_{ee} = E[(x-m_x-a)(x-m_x-a)^T] = R_{xx}-m_xm_x^T+aa^T$
#
# 要使：$R_{ee} = min$ 则 $aa^T = <a,a> = 0$ , 则 $a = 0$
#
# 所以：$\tilde{x} = m_x$且 $R_{ee} = Rxx-m_xm_x^T = cov(x,x) = \Sigma_x$
# <font>

# %% [markdown]
# ### 1.8 $ 已知\varepsilon = Ay，这里 \varepsilon = [\varepsilon_0 \quad \varepsilon_1 \quad \varepsilon_2 \quad \varepsilon_3 ]^T,y = [y_0 \quad y_1 \quad y_2 \quad y_3 ],A = \begin{bmatrix}
# 1 & 0 & 0 & 0 \\
# a_{11} & 1 & 0 & 0 \\
# a_{22} & a_{21} & 1 & 0 \\
# a_{33} & a_{32} & a_31 & 1 \\
# \end{bmatrix}\\
# 求y_0与y_2之间的部分相关系数Y_2及y_0与y_3之间的部分相关系数Y_3\\ $
# <font color = blue>
# $解：\\
# 设e_0,e_2,e_3分别为y_0，y_2，y_3 上的单位方向矢量，由正交分解定理，有:\\
# y_0 = e_0 + E[y_0y_1^T][y_1y_1^T]^{-1}y_1\\
# y_2 = e_2 + E[y_2y_1^T][y_1y_1^T]^{-1}y_1\\
# y_3 = e_3 + E[y_3y_1^T][y_1y_1^T]^{-1}y_1\\
# 由 \varepsilon = Ay得\\
# \begin{split}
# \varepsilon_2 &= a_{22}y_0 + a_{21}y_1+y_2\\
#  &= a_{22}e_0 + a_{22}E[y_0y_1^T][y_1y_1^T]^{-1}y_1+a_{21}y_1+e_2+E[y_2y_1^T][y_1y_1^T]^{-1}y_1
# \end{split}\\
# \because \varepsilon_2 \perp y_1 => E[\varepsilon_2y_1^T] = a_{22}E[y_0y_1^T]+a_{21}E[y_1y_1^T]+E[y_2y_1^T] = 0 \\
# \therefore \varepsilon_2 = a_{22}e_0+e_2\\
# \because \varepsilon_2 \perp \{y_0^T,y_1^T\},e_0 \in \{y_0^T,y_1^T\},故e_0 \perp \varepsilon_2,即E[\varepsilon_2e_0^T]=0 \\
# \quad a_{22}E[e_0e_0^T]+E[e_2e_0^T]=0 \\
# \quad-a_{22} = E[e_2e_0^T]E[e_0e_0^T]^{-1} \\
# \therefore Y_2 = E[e_2e_0^T]E[e_0e_0^T]^{-1} = -a_{22}\\
# 同理：Y_3 = E[e_3e_0^T]E[e_0e_0^T]^{-1} = -a_{33}
# $
# <font>

# %% [markdown]
# ### 1.15 $用谱分解定理对有理功率谱,s_{xx}(z) = \frac{0.36}{(1-0.8z^{-1})(1-0.8z)} +1 进行分解\\
# 谱分解定理：s_{yy}(z)=\delta_{\varepsilon}^2B(z)B(z^{-1})=\delta_{\varepsilon}^2[1-az^{-1}][1-az]
# $
#
# <font color = blue>
# $
# 由谱分解定理得：
# s_{xx}(z) = \delta_{\varepsilon}^2B(z)B(z^{-1})
# =\frac{\delta_{\varepsilon}^{2}[1-az^{-1}][1-az]}{(1-0.8z^{-1})(1-0.8z)}
# =\frac{0.36}{(1-0.8z^{-1})(1-0.8z)}+1\\
# 等式右侧=\frac{0.36+(1-0.8z^{-1})(1-0.8z)}{(1-0.8z^{-1})(1-0.8z)}=\frac{2-0.8z-0.8z^{-1}}{(1-0.8z^{-1})(1-0.8z)}\\
# 等式左侧=\frac{\delta_{\varepsilon}^2[1-az-az^{-1}+a^2]}{(1-0.8z^{-1})(1-0.8z)}\\
# 可联立方程组：\begin{cases}
# \delta_{\varepsilon}^2(a^2+1) =2\\
# \delta_{\varepsilon}^2a = 0.8
# \end{cases}
# =>
# \begin{cases}
# a = 0.5\\
# \delta_{\varepsilon}^2 = 1.6
# \end{cases}\\
# \therefore s_{xx}(z)= \frac{1.6[1-0.5z^{-1}][1-0.5z]}{(1-0.8z^{-1})(1-0.8z)}
# $
#
# <font>

# %% [markdown]
# ### 1.17$ 有一个三维随机矢量y=[y_1 \quad y_2 \quad y_3],其自相关函数为R_{ij}=E[y_iy_j],i,j = 1,2,3\\求该随机矢量的新息表达式$
#
# <font color = red>
# 用到的变换式：
#
# $b_{ni}=E[y_n\varepsilon_i^T]E[\varepsilon_i\varepsilon_i^T]^{-1}\\
# \varepsilon_n = y_n-b_{n(n-1)}y_{n-1} \quad \varepsilon_1 = y_1\\
# R_{ij}=R_{yy}(i-j)\\
# R_{xx}=E[xx^T]$
# <font>
#
# ---
#
# <font color = blue>
# $
# \begin{bmatrix}
# y_1\\y_2\\y_3
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1&0&0\\
# b_{21}&1&0\\
# b_{31}&b_{32}&1
# \end{bmatrix}
# \begin{bmatrix}
# \varepsilon_1\\
# \varepsilon_2\\
# \varepsilon_3
# \end{bmatrix}\\
# b_{21} = E[y_2\varepsilon_1^T]E[\varepsilon_1\varepsilon_1^T]^{-1}=E[y_2y_1^T]E[y_1y_1^T]^{-1}=\frac{R_{21}}{R_{11}}=\frac{R_{YY}(1)}{R_{YY}(0)}\\$
# $b_{31} = E[y_3\varepsilon_1^T]E[\varepsilon_1\varepsilon_1^T]^{-1}=\frac{R_{31}}{R{11}}=\frac{R_{YY}(2)}{R_{YY}(0)}$
#
# $\begin{split}
# b_{32} &= E[y_3\varepsilon_2^T]E[\varepsilon_2\varepsilon_2^T]^{-1}\\
# &=E[y_3(y_2-b_{21}y_1)^T]E[(y_2-b_{21}y_1)(y_2-b_{21}y_1)^T]^{-1}\\
# &={E[y_3y_2^T]-b_{21}E[y_3y_1^T]}{E[y_2y_2^T]-2b_{21}E[y_2y_1^T]+b_[21]^2E[y_1y_1^T]}^{-1}\\
# &=(R_{32}-\frac{R_{21}}{R_{11}}R_{31})(R_{22}-2\frac{R_{21}}{R_{11}}R_{21}+\frac{R_{21}^2}{R_{11}^2}R_{11})^{-1}\\
# &=[R_{YY}(1)-\frac{R_{YY}(1)R_{YY}(2)}{R_{YY}(0)}][R_{YY}(0)-\frac{R_{YY}(1)^2}{R_{YY}(0)}]^{-1}\\
# &=\frac{R_{YY}(1)[R_{YY}(0)-R_{YY}(2)]}{R_{YY}(0)^2-R_{YY}(1)^2}
# \end{split}$
# <font>

# %% [markdown]
# ### 2.3 $设信号s(n)的自相关序列为R_{ss}(m)=0.8^{|m|},m=0,\pm 1,\pm2 \cdots,\\观测信号为x(n) = s(n)+v(n)式中v(n)是方差为0.45的零均值白噪声，它与s(n)相互统计独立\\试设计一个长为N=3的滤波器来处理x(n)，使其输出\hat{s(n)}与s(n)的差的均方值最小
# $
#
# <font color = blue>
# $\begin{split}
# P&= E[s(n)x(n)]\\
# &=E[s(n)[s(n)+v(n),s(n-1)+v(n-1),s(n-2)v(n-2)]^T]\\
# &=E[s(n)s(n),s(n)s(n-1),s(n)s(n-2)]^T\\
# &=[R(0),R(1),R(2)]^T\\
# \end{split}\\
# R(m) = 0.8^{|m|}=>R(0)=1,R(1)=0.8,R(2)=0.64 \\
# \begin{split}
# R&=E[x(n)x(n)^T] = E[[s(n)+v(n),s(n-1)+v(n-1),s(n-2)+v(n-2)][s(n)+v(n),s(n-1)+v(n-1),s(n-2)+v(n-2)]^T]\\
# &=\begin{bmatrix}
# R(0)&R(1)&R(2)\\
# R(1)&R(0)&R(1)\\
# R(2)&R(1)&R(0)
# \end{bmatrix}
# +\begin{bmatrix}
# \delta v^2&0&0\\
# 0&\delta v^2&0\\
# 0&0&\delta v^2
# \end{bmatrix}\\
# &=\begin{bmatrix}
# 1&0.8&0.64\\
# 0.8&1&0.8\\
# 0.64&0.8&1
# \end{bmatrix}
# +\begin{bmatrix}
# 0.45&0&0\\
# 0&0.45&0\\
# 0&0&0.45
# \end{bmatrix}\\
# &=\begin{bmatrix}
# 1.45&0.8&0.64\\
# 0.8&1.45&0.8\\
# 0.64&0.8&1.45
# \end{bmatrix}
# \end{split}\\
# |R|=1.417905\\
# R^* = \begin{bmatrix}
# 1.4625&-0.648&-0.288\\
# -0.648&1.6929&-0.648\\
# -0.288&-0.648&1.4625
# \end{bmatrix}\\
# P = \begin{bmatrix}
# 1\\
# 0.8\\
# 0.64
# \end{bmatrix}\\
# h_{opt} = R^{-1}P = [0.5328,0.2057,0.0914]^T
# $
# <font>

# %% [markdown]
# ### 2.4 $设有一平稳随机过程，其自相关序列为R_{ss}(0)=1,R_{ss}(\pm1)=0.5,R_{ss}(m) = 0(m=\pm2,\pm3,\cdots)\\
# 在传输该 随机过程的一个取样序列s(n)时，混入了一方差为0.45的零均值平稳白噪声v(n),假设噪声与信号统计独立。\\
# 设计一因果IIR维纳滤波器，当x(n) = s(n)+v(n)会为输入时，输出为\hat{s(n)}并计算圴方误差
# $
#
# ---
# <font color = blue>
# 如果IIR维纳滤波器的传输函数$$H_c(z)=\frac{1}{\delta_{\varepsilon}^2B(z)}\left[\frac{S_{xs(z)}}{B(z^{-1})}\right]$$
# 设计因果IIR维纳滤波器的步骤如下：
#
# 1. 求出功率谱：$S_{ss}(z),S_{xs}(z),S_{xx}(z)\\
# \quad S_{ss}(z)可直接根据给定序列求出 \\
# \quad S_{xs}(z)用x(n),s(n)的系数关系与S_{ss}(z)相乘得到\\
# \quad S_{xx}(z)用S_{xs}(z)加上噪声发v(n)的方差即可\\
# $
#
# $ S_{ss}(z) = z^{-1}[R_{ss}(m)] = \lim_{m=-\infty}^{+\infty}R_{ss}(m)z^{-m} = 1+0.5z+0.5z^{-1}\\
# S_{sx}(z) = S_{ss}(z)=1+0.5z+0.5z^{-1}\\
# S_{xx}(z) = S_{ss}(z)+S_{w}(z) = 1.45+0.5z+0.5z^{-1}\\
# $
#
# 2. 将$S_{xx}(z)$用谱分解的形式设出来与第1步联立方程得出$\sigma_i^2$和B(z)与$B(z^{-1})$
#
# $
# 设S_{xx}(z) = \sigma_i^2(1-\delta z)(1-\delta z^{-1})\\
# \begin{cases}
# (1+\delta^2)\sigma_i^2 = 1.45\\
# \delta\sigma_i^2 = -0.5\\
# \end{cases}
# =>
# \begin{cases}
# \delta = -0.4\\
# \sigma_i^2 = 1.25\\
# \end{cases}\\
# B(z)=1+0.4z^{-1}\\
# B(z^{-1}) = 1+0.4z\\
# $
#
#
# 3. 求$\frac{S_{xs}(z)}{B(z^{-1})}$的因果部分
# $
# \frac{S_{sx}(z)}{B(z^{-1})} = \frac{1+0.5z+0.5z^{-1}}{1+0.4z} = 0.8+0.5z^{-1}+\frac{0.18z}{1+0.4z}\\
# \left[\frac{S_{sx}(z)}{B(z^{-1})}\right]_+=0.8+0.5z^{-1}\\
# H_1(z) = \frac{1}{\sigma_i^2B(z)}\left[\frac{S_{sx}(z)}{B\left(z^{-1}\right)}\right] = \frac{0.8+0.5z^{-1}}{1.25(1+0.4z^{-1})}=\frac{0.4+0.64z}{z+0.4}$
# 4. 代入传输函数方程
# <font>

# %% [markdown]
# ### $已知一阶马尔柯夫过程的信号模型为：s(n)=0.6s(n-1)+w(n)
# 式中，w(n)是方差为0.82的零均值白噪声\\对s(n)进行观测，得到：x(n) = s(n) +v(n),
# 式中，v(n)是方差为1的零均值白噪声\\设计一因果IIR维纳滤波器，对x(n)进行处理以得到s(n)的最佳估计\\
# $
# $
# (1):求滤波器的冲激响应：
# 由信号模型可得系统传输函数：\\H(z) = \frac{1}{1-0.6z^{-1}}\\
# S_{ss}(z) = S_{ww}(z)H(z)H(z^{-1}) = \frac{0.8z}{(1-0.6z^{-1})(1-0.6z)}\\
# S_{sx}(z) = S_{ss}(z) = \frac{0.8z}{(1-0.6z^{-1})(1-0.6z)}\\
# S_{xx}(z) = S_{sx}(z)+S_{vv}(z) = \frac{0,82}{(1-0,6z^{-1})(1-0.6z)}+1\\
# 对S_{xx}(z)进行谱分解\\
# S_{xx}(z) = \frac{0.8z}{(1-0.6z^{-1})(1-0.6)}+1 = \frac{\sigma_{\varepsilon}^2(1-\delta z^{-1})(1-\delta z)}{(1-0.6z^{-1})(1-0.6z)}\\
# \begin{cases}
# \sigma_{\varepsilon}^2(1+\delta^2) = 2.18\\
# \frac{\delta}{1+\delta^2} = \frac{0.6}{2.18}
# \end{cases}
# =>
# \begin{cases}
# \delta = 0.3\\
# \sigma_{\varepsilon}^2 = 2
# \end{cases}\\
# \therefore B(z) = \frac{1-0.3z^{-1}}{1-0.6z^{-1}} , B(z^{-1})=\frac{1-0.3z}{1-0.6z}\\
# \frac{S_{sx}(z)}{B(z^{-1})} = \frac{0.8z}{(1-0.6z^{-1})(1-0.6z)}\cdot \frac{1-0.6z}{1-0.3z} = \frac{1}{1-0.6z^{-1}}+\frac{0.3}{1-0.3z}\\
# \therefore \left[\frac{S_{sx}(z)}{B(z^{-1})}\right]_+ = \frac{1}{1-0.6z^{-1}}\\
# H_c(z)=\frac{1}{\sigma_{\varepsilon}^2B(z)}\left[\frac{S_{sc(z)}}{B(z^{-1})}\right] = \frac{1}{2\cdot \frac{1-0.3z^{-1}}{1-0.6z^{-1}}} = \frac{0.5z}{z-0.3}\\
# $
#
# $(2)：若用x(n)作为s(n)的估计与设计的滤波器的片进行比较，后者的估计误差均方值改进了多少分贝：\\
# \therefore z^{-1}[H_c(z)] = z^{-1}\left[\frac{0.5z}{z-0.3}\right] = 0.5(0.3)^{n}\delta(n)\\
# \begin{split}
# \xi_{min}(n)|_{n=0}&=\frac{1}{2\pi j}\oint_{uc}[S_{ss}(z)-H_c(z)S_{sx}(z^{-1})]z^{-1}\mathrm{d}z\\
# &=\frac{1}{2\pi j}\oint_{uc}\left[\frac{0.82}{(1-0.6z)(1-0.6z^{-1})}-\frac{0.5}{1-0.3z^{-1}}\cdot\frac{0.82}{(1-0.6z)(1-0.6z^{-1})}\right]z^{-1}\mathrm{d}z\\
# &= \frac{1}{2\pi j}\oint_{uc}\left[\frac{0.82*0.5}{(1-0.6z)(z-0.3)}\right]\mathrm{d}z\\
# &=\frac{0.82*0.5}{1-0.6z}|_{z=0.3} = 0.5\\
# \end{split}\\
# 若用x(n)作s(n)的估计，则估计误差为：\\
# e(n) = s(n)-x(n)=-v(n)\\
# \xi(n) = E[e^2(n)]=1\\
# \therefore \triangle = lolg\frac{1}{0.5} = 3dB
# $

# %% [markdown]
# ### 2.11$在维纳滤波器的实际应用中，常采用如图所示的接法，图中s(n)是确定性原始信号，s(n)+N_1(n) 和s(n)+N_2(n)是在两个不相关的噪声环境中测量得到的信号，滤波器输出y(n)是原始有用信号s(n)的最佳估计，即y(n)=\hat{s}(n)\approx s(n).\\
# 试解释为什么这种接法更符合维纳滤波器理论的假设条件，因而滤波器效果会更好$
# <img src="https://raw.githubusercontent.com/ghhu-dai/jupyter/master/jupyter%E7%AC%94%E8%AE%B0/%E5%85%B6%E4%BB%96/%E6%95%B0%E4%BF%A12_11.png" width="500" height="300" />
#
# <font color = green>
#     答：由于在实际中常需对非随机信号进行滤波，故采用互补型维纳滤波，其中有两个滤波器，一个为高通，另一个为低通，但这里由于输入的信号是非平稳的，不能直接进行维纳滤波，这样就需对滤波模型进行改进，采用图中的模型后，维纳滤波器的输入就为平稳的随机信号，符合维纳滤波理论
# <font>

# %% [markdown]
# ### 3.3$图中所示的是一个具有两个权系数的单输入的自适应线性组合器的原理图，\\信号每个周期有N个取样，N>2,以保证输入取样值不至于全为零$
# <img src="https://raw.githubusercontent.com/ghhu-dai/jupyter/master/jupyter%E7%AC%94%E8%AE%B0/%E5%85%B6%E4%BB%96/%E6%95%B0%E4%BF%A13_3.png"
# width="500" height="300" />
#
#
# $
# (1). 求性能曲面函数：\\
# \xi(n) = E[d^2(n)]+W^TRW-2P^TW\\
# R =E[x(n)x^T(n)]=\begin{bmatrix}
# E[x^2(n)]&E[x(n)x(n-1)]\\
# E[x(n-1)x(n)] & E[x^2(n-1)]\\
# \end{bmatrix}\\
# P = E[d(n)x(n)] = E[d(n)x(n)\quad d(n)x(n-1)]^T\\
# W(n)=[W_0(n)\quad W_1(n_0)]\\
# x(n)=\sin(\frac{2\pi}{N}n),d(n)=2\cos(\frac{2\pi}{N}n)\\
# E[x^2(n)] = \frac{1}{2},E[x^2(n-1)] = \frac{1}{2}\\
# E[x(n)x(n-1)] = E[\sin(\frac{2\pi}{N})n\sin(\frac{2\pi}{N}n-\frac{2\pi}{N})]=\frac{1}{2}E[\cos(\frac{2\pi}{N})]=\frac{1}{2}\cos(\frac{2\pi}{N})\\
# E[d^2(n)]=2\\
# E[d(n)x(n-1)]=E[\cos(\frac{2\pi}{N}n)\cdot \sin(\frac{2\pi}{N}n-\frac{2\pi}{N})]=-E[\sin(\frac{2\pi}{N})]=-\sin(\frac{2\pi}{N})\\
# \begin{split}
# \xi(n)&=E[d^2(n)]+W^TRW-2P^TW\\
# &=2+\begin{bmatrix}
# W_0(n)\\
# W_1(n)
# \end{bmatrix}^T\begin{bmatrix}
# \frac{1}{2}&\frac{1}{2}\cos(\frac{2\pi}{N})\\
# \frac{1}{2}\cos(\frac{2\pi}{N})&\frac{1}{2}
# \end{bmatrix}[W_0(n) \quad W_1(n)]^T-2\left(E[d(n)x(n)\quad d(n)x(n-1)]\begin{bmatrix}W_0(n)\\W_1(n)\end{bmatrix}\right)\\
# &=2+(\frac{1}{2}W_0+\frac{1}{2}W_1\cos(\frac{2\pi}{N})+\frac{1}{2}W_0\cos(\frac{2\pi}{N})+\frac{1}{2}W_1)\begin{pmatrix}W_0\\W_1\end{pmatrix}-2\left(0-\sin(\frac{2\pi}{N})\right)\begin{pmatrix}W_0\\W_1\end{pmatrix}\\
# &=0.5(W_0^2+W_1^2)+W_0W_1\cos(\frac{2\pi}{N})+2W_1\sin(\frac{2\pi}{N})+2
# \end{split}\\
# (2).当N=5时，\xi(n) = 0.5(W_0^2+W_1^2)+W_0W_1\cos(\frac{2\pi}{5})+2W_1\sin(\frac{2\pi}{5})+2\\
# (3).\triangledown = \frac{\mathrm{d}\xi}{\mathrm{d}W} = \begin{pmatrix}\frac{\mathrm{d}\xi}{\mathrm{d}W_0}&\frac{\mathrm{d}\xi}{\mathrm{d}W_1}\end{pmatrix}^T\\
# \frac{\mathrm{d}\xi}{\mathrm{d}W_0} = W_0+W_1\cos(\frac{2\pi}{N})\\
# \frac{\mathrm{d}\xi}{\mathrm{d}W_1}=W_1+W_0\cos(\frac{2\pi}{N})+2\sin(\frac{2\pi}{N})\\
# (4).求最佳权重矢量\\
# \begin{split}
# W_* &= R_{-1}\cdot P\\
# &=\begin{pmatrix}
# \frac{1}{2}&\frac{1}{2}\cos(\frac{2\pi}{N})\\
# \frac{1}{2}\cos(\frac{2\pi}{N})&\frac{1}{2}
# \end{pmatrix}^{-1}\cdot\begin{pmatrix}0\\-\sin(\frac{2\pi}{N})\end{pmatrix}\\
# &=\begin{pmatrix}\frac{2\cos(\frac{2\pi}{N})}{\sin(\frac{2\pi}{N})}\\
# -\frac{2}{\sin(\frac{2\pi}{N})}\end{pmatrix}\\
# &=\left[2\cot(\frac{2\pi}{N})\quad -2\csc(\frac{2\pi}{N}) \right]^T
# \end{split}\\
# (5).\\
# \begin{split}
# \xi_{min}&=E[d^2(n)]-P^TW^*\\
# &=2-E[d(n)x(n)\quad d(n)x(n-1)]\begin{bmatrix}2\cot(\frac{2\pi}{N})\\
# -2\csc(\frac{2\pi}{N})\end{bmatrix}\\
# &=2-\left(0-\sin(\frac{2\pi}{N})\right)\begin{pmatrix}2\cot(\frac{2\pi}{N})\\-2\csc(\frac{2\pi}{N})\end{pmatrix}\\
# &=2-2\\
# &=0
# \end{split}
# $

# %% [markdown]
# ### 3.5$已知R=\begin{bmatrix}1&2\\2&1
# \end{bmatrix},P=\begin{bmatrix}7\\8\end{bmatrix},E[d^2(n)]=42$
#
# $
# (1)写出性能曲面公式：\\
# \begin{split}
# \xi(n) &= E[d^2(n)]+WRW-2P^TW\\
# &=
# \end{split}
# $
